# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install ultralytics
# !pip install roboflow

# %%
from ultralytics import YOLO
import os
from IPython.display import display, Image
from IPython import display
display.clear_output()
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.19 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 30.1/78.2 GB disk)

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="hctjEIIooQ2bdbyplJER")
project = rf.workspace("tablicefilip").project("anpr-d7qnq")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.196 is required but found version=8.2.19, to fix: `pip install ultralytics==8.0.196`
# ...
# Extracting Dataset Version Zip to ANPR-1 in yolov8:: 100%|██████████| 9312/9312 [00:01<00:00, 5597.16it/s]

# %%
# !yolo task=detect mode=train model=yolov8m.pt data=/content/ANPR-1/data.yaml epochs=20 imgsz=640
# Out:
# ...
# 100% 49.7M/49.7M [00:00<00:00, 312MB/s]
# Ultralytics YOLOv8.2.19 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !zip -r medium.zip yolo-medium/
# Out:
# Streaming output truncated to the last 5000 lines.
#   adding: yolo-medium/ANPR-1/train/labels/819dcc28c86cd8a02_jpg.rf.58e20a8e4b71bb104c715c725ad02b99.txt (deflated 15%)
#   adding: yolo-medium/ANPR-1/train/labels/dso8xg84l2ha1_jpg.rf.3c2e183f76c1e5571dfe022b6b4d8718.txt (deflated 48%)
#   adding: yolo-medium/ANPR-1/train/labels/ee4j45maswba1_jpg.rf.170205a8d97762a4566db39b3228d63f.txt (deflated 58%)
#   adding: yolo-medium/ANPR-1/train/labels/419f8a15e8c72891_jpg.rf.0143c97c1e0a322060e8abeb31ad9928.txt (deflated 5%)
#   adding: yolo-medium/ANPR-1/train/labels/3vqna87qsmma1_jpg.rf.141fb4b9798c9bdbb2b1f6a00ab085c6.txt (deflated 51%)
#   adding: yolo-medium/ANPR-1/train/labels/BJU0Td3ImLhLin6z3eKfKIoa0SjrPoG8C9wlJu8n5WM_jpg.rf.f0577edd2eb4251582bdb25c7f5a013e.txt (deflated 49%)
#   adding: yolo-medium/ANPR-1/train/labels/mtg6u7luzmga1_jpg.rf.5e487c7de321a953d8620dc2c5fe5dec.txt (deflated 54%)
# ...

# %%
from google.colab import files
files.download('medium.zip')
